# %% [markdown]
# <a href="https://colab.research.google.com/github/sadaf-iqbal17/Pytorch/blob/main/Pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
